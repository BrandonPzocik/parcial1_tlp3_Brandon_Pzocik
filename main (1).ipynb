# %% [markdown]
# # Examen Parcial n°1 2da Parte - TLP3 - Python para Ciencia de Datos.

# %% [markdown]
# **A partir del datasets brindado, realizar los siguientes procedimientos:**
#
# * Importar datasets con Pandas.
# * Explorar los datos con los metodos correspondientes.
# * Limpieza de los datos (Normalización de datos).
# * Obtener estadisticas.
# * Mostrar los datos procesados con graficos utilizando la libreria Matplotlib.
# * Exportar el contenido a un archivo sqlite utilizando PANDAS.
#
#
# **Importante: Se debe documentar cada procedimiento realizado, siguiendo la siguiente estructura:**
#
# 1. Celda de Markdown (Documentación)
# 2. Código (Sin comentarios, se debe documentar lo sufiente solo en la celda de markdown).
#
#
# ### Criterios de Evaluación:
#
# 1. No esta permitido el uso de IAs durante el examen. (Desactivar Copilot o cualquier herramienta de IA para autocompletar codigo.)
#
# 2. Se deben utilizar nombres de variables descriptivos y claros (Utilizar la nomeclatura correspondiente para los nombres de variables).
#
# 3. Comentarios claros y concisos que expliquen el propósito de cada sección del código en una celda de markdown antes del código.
#
# 4. Utilizar mensajes de commit descriptivos. (Puedes utilizar la extension CONVENTIONAL COMMIT de VS-CODE).
#
# 5. Entrega en tiempo y forma (Parciales entregados fuera de hora o con commits pasados el horario de entrega quedará invalidado.)
#
# 6. Todo el código desarrollado debe ser subido a un repositorio en GitHub (el nombre del repositorio de seguir la siguiente estructura:
# **parcial1_tlp3_nombre_apellido**).
#
# 7. Para resolver las actividades se debe insertar casillas de codigo entre cada actividad del cuaderno de Jupyter.
#
# 8. Deben trabajar con el datasets adjunto.
#
# 9. Una vez finalizado el examen, los resultados deben quedar guardados debajo de cada celda (NO EJECUTAR LA OPCIÓN "borrar todas las salidas").
#
# **Importante:** Una vez finalizado el examen, marcar como completado en el classroom.

# %% [markdown]
# ## Actividades:
# ### 1. Importación del Dataset con Pandas
#
# En esta sección, se debe utilizar la librería Pandas para cargar el archivo CSV que contiene los datos de VENTAS en un DataFrame.
#
# ### 2. Exploración Inicial de los Datos
#
# A continuación, se deben emplear métodos de Pandas para obtener una visión general del dataset.
# - 2.1: Visualizar las primeras filas y ultimas.
# - 2.2: Obtener informacion del df con su metodo correspondiente.
# - 2.3: Hacer un conteo de valores nulos.
#
# ### 3. Limpieza y Normalización de los Datos
#
# - 3.1. Esta etapa crucial deben aplicar la corrección de diversos errores presentes en el dataset. Se abordarán los valores faltantes (Deben aplicar los metodos que ustedes crean convenientes **(Solo 1)**, por ejemplo: Eliminación de filas, cubrir valores con media, mediana, etc.)
# - 3.2: La columna Fecha deberan pasarla al tipo datetime con su metodo correspondiente.
# - 3.3: Corregir las mayusculas en el caso de Nombre y Apellido (Si es que corresponde.)
#
#
# ### 4. Obtención de Estadísticas Descriptivas
#
# Después de la limpieza, deben hacer lo siguiente:
#
# - 4.1: calcular nuevamente las estadísticas descriptivas para observar el impacto del proceso de limpieza en los datos numéricos.
# - 4.2: Calcular estadísticas específicas por grupo (Agrupar dos columnas).
#
# ### 5. Visualización de los Datos con Matplotlib
#
# En esta sección, deben utilizar la librería Matplotlib para crear **UNA** visualización que permitan comprender mejor los datos de ventas.El grafico es a elección, puede crear **UNO** de los siguientes: histogramas, diagramas de dispersión, gráficos de barras y graficos de torta.
#
# ### 6. Exportación a Archivo SQLite
#
# Finalmente, deben utilizar la funcionalidad de Pandas para guardar el DataFrame procesado en una base de datos SQLite. Deben hacer una conexión y hacer una consulta para ver si los datos fueron cargados correctamente.

# %% [markdown]
# ### punto 1
# - se importa pandas y se le asigna el alias pd
# - se lee el archivo csv con .read_csv()

# %%
import pandas as pd 

df = pd.read_csv("ventas.csv")

# %% [markdown]
# ### punto 2
# - se utiliza el metodo .head() para visualizar las primeras filas y el .tail() para visualizar las ultimas filas del dataframe
# - se utiliza .info() para obtener una descripcion general
# - para un conteo de los valores nulos se utiliza isnull().sum()
# - con el  metodo .describe() se obtiene una estadistica de toda la tabla

# %%
df.head()
# Out:
#    ID_Venta Nombre_Cliente Apellido_Cliente       Fecha  \
# 0         1            Ana           García  01-05-2024
# 1         2         Carlos            López  2024-01-08
# 2         3          sofía         martínez  2024-01-12
# 3         4          pedro        rodríguez  2024-01-15
# 4         5          Laura          Sánchez  18-01-2024
#
#                 Producto  Cantidad  Precio_Unitario  Total_Venta  \
# 0                 Laptop         1          1200.50      1200.50
# 1      Mouse Inalámbrico         2            25.75        51.50
# 2       Teclado Mecánico         1            75.99        75.99
# 3    Monitor 24 pulgadas         1              NaN          NaN
# 4  Auriculares Bluetooth         1            99.95        99.95
#
#               Metodo_Pago Region
# 0      Tarjeta de Crédito  Norte
# 1                Efectivo    Sur
# 2  Transferencia Bancaria   Este
# 3       Tarjeta de Débito  Oeste
# 4      Tarjeta de Crédito  Norte

# %%
df.tail()
# Out:
#      ID_Venta Nombre_Cliente Apellido_Cliente       Fecha  \
# 100       101        Agustín           Torres  2024-10-08
# 101       102         Camila             Vega  2024-10-11
# 102       103           Juan            Rojas  2024-10-15
# 103       104          Lucía            Silva  2024-10-18
# 104       105          mateo             luna  2024-10-22
#
#                  Producto  Cantidad  Precio_Unitario  Total_Venta  \
# 100        Pen Drive 64GB         4             8.75         35.0
# 101         Laptop Ligera         1              NaN       1180.0
# 102                   NaN         1            48.99          NaN
# 103     Teclado Bluetooth         1            78.20         78.2
# 104  Monitor para Oficina         1             2.00        210.5
#
#                 Metodo_Pago Region
# 100       Tarjeta de Débito  Oeste
# 101      Tarjeta de Crédito  Norte
# 102                Efectivo    Sur
# 103  Transferencia Bancaria   Este
# 104       Tarjeta de Débito  Oeste

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_Venta          105 non-null    int64
#  1   Nombre_Cliente    105 non-null    object
#  2   Apellido_Cliente  105 non-null    object
#  3   Fecha             105 non-null    object
#  4   Producto          101 non-null    object
#  5   Cantidad          105 non-null    int64
#  6   Precio_Unitario   92 non-null     float64
#  7   Total_Venta       92 non-null     float64
#  8   Metodo_Pago       94 non-null     object
#  9   Region            100 non-null    object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 8.3+ KB

# %%
df.isnull().sum()
# Out:
# ID_Venta             0
# Nombre_Cliente       0
# Apellido_Cliente     0
# Fecha                0
# Producto             4
# Cantidad             0
# Precio_Unitario     13
# Total_Venta         13
# Metodo_Pago         11
# Region               5
# dtype: int64

# %%
df.describe()
# Out:
#          ID_Venta    Cantidad  Precio_Unitario  Total_Venta
# count  105.000000  105.000000        92.000000    92.000000
# mean    53.000000    1.190476       240.609239   251.062609
# std     30.454885    0.538788       392.861883   378.417849
# min      1.000000    1.000000         2.000000     0.000000
# 25%     27.000000    1.000000        48.990000    55.000000
# 50%     53.000000    1.000000        90.990000    97.250000
# 75%     79.000000    1.000000       181.675000   213.000000
# max    105.000000    4.000000      1800.990000  1800.990000

# %% [markdown]
# ### punto 3
# ## 3.1
# - el atributo dtypes para ver solo el tipo de datos de cada columna para saber con que tipos vamos a estar trabajando
# - se utiliza el metodo fillna() para rellenar los valores nulos con la mediana para no verse afectado por valores extremos de toda la columna, le pasamos como segundo parametro el inplace = True para que el cambio se haga en el dataframe original
# - despues de cada cambio realizado corroboro con .isnull().sum() para ver si efectivamente no hay valores nulos en la columna trabajada
# - los 4 valores nulos de la columna productos se reemplazaran por "producto sin nombre"
# - los 11 valores nulos en metodo de pago seran reemplazado por "metodo sin especificar"
# - los 5 valores nulos en region seran reemplazosodr por "region no especificada"
#
# ## 3.2
# - con el metodo .to_datatime paramos los valores a tipo fecha y se usa el combine_first para combinar a un solo formato de fecha
#
# ## 3.3
#  - para capitalizar el nombre y apellido usamos las funciones de str .title() para pasar a mayuscula las primera letra de cada palabra y .strip() para eliminar espacion adelante y atras de la palabraa

# %%
df.dtypes
# Out:
# ID_Venta              int64
# Nombre_Cliente       object
# Apellido_Cliente     object
# Fecha                object
# Producto             object
# Cantidad              int64
# Precio_Unitario     float64
# Total_Venta         float64
# Metodo_Pago          object
# Region               object
# dtype: object

# %%
df["Precio_Unitario"].fillna(df["Precio_Unitario"].median(), inplace= True)
df.head(20)
# Out:
# C:\Users\IPF-2025\AppData\Local\Temp\ipykernel_3496\4109159866.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Precio_Unitario"].fillna(df["Precio_Unitario"].median(), inplace= True)
#     ID_Venta Nombre_Cliente Apellido_Cliente       Fecha  \
# 0          1            Ana           García  01-05-2024
# 1          2         Carlos            López  2024-01-08
# 2          3          sofía         martínez  2024-01-12
# 3          4          pedro        rodríguez  2024-01-15
# ...

# %%
df.isnull().sum()
# Out:
# ID_Venta             0
# Nombre_Cliente       0
# Apellido_Cliente     0
# Fecha                0
# Producto             4
# Cantidad             0
# Precio_Unitario      0
# Total_Venta         13
# Metodo_Pago         11
# Region               5
# dtype: int64

# %%
df["Total_Venta"].fillna(df["Total_Venta"].median(), inplace= True)
df.head()
# Out:
# C:\Users\IPF-2025\AppData\Local\Temp\ipykernel_3496\3428545765.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Total_Venta"].fillna(df["Total_Venta"].median(), inplace= True)
#    ID_Venta Nombre_Cliente Apellido_Cliente       Fecha  \
# 0         1            Ana           García  01-05-2024
# 1         2         Carlos            López  2024-01-08
# 2         3          sofía         martínez  2024-01-12
# 3         4          pedro        rodríguez  2024-01-15
# ...

# %%
df.isnull().sum()
# Out:
# ID_Venta             0
# Nombre_Cliente       0
# Apellido_Cliente     0
# Fecha                0
# Producto             4
# Cantidad             0
# Precio_Unitario      0
# Total_Venta          0
# Metodo_Pago         11
# Region               5
# dtype: int64

# %%
df["Producto"].fillna("Producto sin nombre", inplace= True)
df.tail()
# Out:
# C:\Users\IPF-2025\AppData\Local\Temp\ipykernel_3496\2299335724.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Producto"].fillna("Producto sin nombre", inplace= True)
#      ID_Venta Nombre_Cliente Apellido_Cliente       Fecha  \
# 100       101        Agustín           Torres  2024-10-08
# 101       102         Camila             Vega  2024-10-11
# 102       103           Juan            Rojas  2024-10-15
# 103       104          Lucía            Silva  2024-10-18
# ...

# %%
df["Metodo_Pago"].fillna("Metodo sin especificar", inplace=True)
df.head(30)
# Out:
# C:\Users\IPF-2025\AppData\Local\Temp\ipykernel_3496\2070165526.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Metodo_Pago"].fillna("Metodo sin especificar", inplace=True)
#     ID_Venta Nombre_Cliente Apellido_Cliente       Fecha  \
# 0          1            Ana           García  01-05-2024
# 1          2         Carlos            López  2024-01-08
# 2          3          sofía         martínez  2024-01-12
# 3          4          pedro        rodríguez  2024-01-15
# ...

# %%
df.isnull().sum()
# Out:
# ID_Venta            0
# Nombre_Cliente      0
# Apellido_Cliente    0
# Fecha               0
# Producto            0
# Cantidad            0
# Precio_Unitario     0
# Total_Venta         0
# Metodo_Pago         0
# Region              5
# dtype: int64

# %%
df["Region"].fillna("region no especificada", inplace=True)
df.isnull().sum()
# Out:
# C:\Users\IPF-2025\AppData\Local\Temp\ipykernel_3496\4157435925.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Region"].fillna("region no especificada", inplace=True)
# ID_Venta            0
# Nombre_Cliente      0
# Apellido_Cliente    0
# Fecha               0
# Producto            0
# Cantidad            0
# Precio_Unitario     0
# Total_Venta         0
# Metodo_Pago         0
# Region              0
# dtype: int64

# %%
fecha1 = pd.to_datetime(df["Fecha"], format="%Y-%m-%d", errors="coerce")
fecha2 = pd.to_datetime(df["Fecha"], format="%d-%m-%Y", errors="coerce")
df["Fecha"] = fecha1.combine_first(fecha2)
df.dtypes
# Out:
# ID_Venta                     int64
# Nombre_Cliente              object
# Apellido_Cliente            object
# Fecha               datetime64[ns]
# Producto                    object
# Cantidad                     int64
# Precio_Unitario            float64
# Total_Venta                float64
# Metodo_Pago                 object
# Region                      object
# dtype: object

# %%
df["Nombre_Cliente"] = df["Nombre_Cliente"].astype(str).str.title().str.strip()
df["Apellido_Cliente"] = df["Apellido_Cliente"].astype(str).str.title().str.strip()
df.head(10)
# Out:
#    ID_Venta Nombre_Cliente Apellido_Cliente      Fecha  \
# 0         1            Ana           García 2024-05-01
# 1         2         Carlos            López 2024-01-08
# 2         3          Sofía         Martínez 2024-01-12
# 3         4          Pedro        Rodríguez 2024-01-15
# 4         5          Laura          Sánchez 2024-01-18
# 5         6          Diego            Pérez 2024-01-22
# 6         7      Valentina           Flores 2024-01-25
# 7         8           Juan          Ramírez 2024-01-29
# 8         9        Martina             Díaz 2024-02-02
# 9        10      Sebastián            Gómez 2024-02-05
#
#                  Producto  Cantidad  Precio_Unitario  Total_Venta  \
# 0                  Laptop         1          1200.50      1200.50
# 1       Mouse Inalámbrico         2            25.75        51.50
# 2        Teclado Mecánico         1            75.99        75.99
# 3     Monitor 24 pulgadas         1            90.99        97.25
# ...

# %% [markdown]
# ### punto 4
# ## 4.1
# - volvemos a hacer el .describe()
#
# ## 4.2
# -Agrupamos nombre por total de venta con el metodo .groupby(), para obtener el promedio de ventas total por cliente
# - agrupamos prducto con su cantidad, para ver un conte de la cantida de cada producto
# - agrupamos el producto con su precio

# %%
df.describe()
# Out:
#          ID_Venta                          Fecha    Cantidad  Precio_Unitario  \
# count  105.000000                            105  105.000000       105.000000
# mean    53.000000  2024-06-21 13:42:51.428571392    1.190476       222.084952
# min      1.000000            2024-01-08 00:00:00    1.000000         2.000000
# 25%     27.000000            2024-04-09 00:00:00    1.000000        55.000000
# 50%     53.000000            2024-07-05 00:00:00    1.000000        90.990000
# 75%     79.000000            2024-09-06 00:00:00    1.000000       165.000000
# max    105.000000            2024-10-22 00:00:00    4.000000      1800.990000
# std     30.454885                            NaN    0.538788       370.809510
#
#        Total_Venta
# count   105.000000
# mean    232.019143
# min       0.000000
# 25%      62.750000
# 50%      97.250000
# 75%     185.200000
# max    1800.990000
# std     357.618804

# %%
df.groupby("Nombre_Cliente")["Total_Venta"].mean()
# Out:
# Nombre_Cliente
# Abril         745.000000
# Agustín       112.600000
# Ana          1200.500000
# Benicio        71.666667
# Benjamín      385.250000
# Bruno         292.916667
# Camila        554.148000
# Carlos         51.500000
# Catalina       91.125000
# Diego          45.500000
# Elena         723.796667
# Emilia        360.844000
# Florencia     147.995000
# Francisco     219.083333
# Gabriel        66.370000
# Isabella      730.000000
# Jerónimo       59.583333
# Joaquín       273.625000
# Juan           68.372500
# Laura          99.950000
# Lautaro        89.166667
# Lucía         348.847500
# Martina       146.562500
# Mateo         121.597500
# Máximo         57.490000
# Mía           130.660000
# Olivia        120.333333
# Paula         100.500000
# Pedro          97.250000
# Renata        965.375000
# Santiago      355.000000
# Santino        33.475000
# Sebastián      65.800000
# Sofía          55.372500
# Thiago         31.095000
# Valentina     129.900000
# ...

# %%
df.groupby("Producto")["Cantidad"].count()
# Out:
# Producto
# Altavoces Inteligentes    2
# Auriculares Bluetooth     2
# Auriculares Deportivos    1
# Auriculares In-Ear        1
# Auriculares Over-Ear      1
#                          ..
# Teclado RGB               1
# Teclado Retroiluminado    1
# Webcam 4K                 1
# Webcam Básica             1
# Webcam HD                 1
# Name: Cantidad, Length: 78, dtype: int64

# %%
df.groupby("Producto")["Precio_Unitario"].unique()
# Out:
# Producto
# Altavoces Inteligentes            [70.0]
# Auriculares Bluetooth     [99.95, 90.99]
# Auriculares Deportivos            [75.5]
# Auriculares In-Ear               [49.99]
# Auriculares Over-Ear            [120.75]
#                                ...
# Teclado RGB                      [110.5]
# Teclado Retroiluminado            [85.0]
# Webcam 4K                        [79.99]
# Webcam Básica                    [90.99]
# Webcam HD                         [45.5]
# Name: Precio_Unitario, Length: 78, dtype: object

# %% [markdown]
# ### punto 5
# - importamos matplotlib
# - se realiza un grafico de barras para representar el promedio de ventas totales por cliente

# %%
import matplotlib.pyplot as plt 
clientes_por_ventas_totales = df.groupby("Nombre_Cliente")["Total_Venta"].mean()
plt.figure(figsize=(8,6))
plt.bar(clientes_por_ventas_totales.index, clientes_por_ventas_totales.values, color="skyblue")
plt.title(" Promedio de ventas totales por cliente")
plt.xlabel("Nombre_Cliente")
plt.ylabel("Total_venta")
plt.xticks(rotation=55)
plt.grid(axis="y")
plt.show()

# %% [markdown]
# ### punto 6
# - importamos sqlite3
# - exportamos a u archivo sqlite

# %%
import sqlite3

conn = sqlite3.connect("base_de_datos_ventas.db")

df.to_sql("ventas_clientes", conn, index= False)

conn.close()

# %%
conn = sqlite3.connect("base_de_datos_ventas.db")

df = pd.read_sql_query("SELECT * FROM ventas_clientes", conn)

conn.close()

df.head()
# Out:
#    ID_Venta Nombre_Cliente Apellido_Cliente                Fecha  \
# 0         1            Ana           García  2024-05-01 00:00:00
# 1         2         Carlos            López  2024-01-08 00:00:00
# 2         3          Sofía         Martínez  2024-01-12 00:00:00
# 3         4          Pedro        Rodríguez  2024-01-15 00:00:00
# 4         5          Laura          Sánchez  2024-01-18 00:00:00
#
#                 Producto  Cantidad  Precio_Unitario  Total_Venta  \
# 0                 Laptop         1          1200.50      1200.50
# 1      Mouse Inalámbrico         2            25.75        51.50
# 2       Teclado Mecánico         1            75.99        75.99
# 3    Monitor 24 pulgadas         1            90.99        97.25
# 4  Auriculares Bluetooth         1            99.95        99.95
#
#               Metodo_Pago Region
# 0      Tarjeta de Crédito  Norte
# 1                Efectivo    Sur
# 2  Transferencia Bancaria   Este
# 3       Tarjeta de Débito  Oeste
# ...
